# %%
import pickle
import pandas as pd

# %%
with open('f1data.pkl', 'rb') as f:
    df = pickle.load(f)

# %%
df
# Out:
#    DriverNumber BroadcastName Abbreviation         DriverId         TeamName  \
# 4             4      L NORRIS          NOR           norris          McLaren
# 1             1  M VERSTAPPEN          VER   max_verstappen  Red Bull Racing
# 81           81     O PIASTRI          PIA          piastri          McLaren
# 63           63     G RUSSELL          RUS          russell         Mercedes
# 16           16     C LECLERC          LEC          leclerc          Ferrari
# 44           44    L HAMILTON          HAM         hamilton         Mercedes
# 55           55       C SAINZ          SAI            sainz          Ferrari
# 14           14      F ALONSO          ALO           alonso     Aston Martin
# 27           27  N HULKENBERG          HUL       hulkenberg     Haas F1 Team
# 11           11       S PEREZ          PER            perez  Red Bull Racing
# 43           43   F COLAPINTO          COL        colapinto         Williams
# ...

# %%
df.shape
# Out:
# (20, 21)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.columns
# Out:
# Index(['DriverNumber', 'BroadcastName', 'Abbreviation', 'DriverId', 'TeamName',
#        'TeamColor', 'TeamId', 'FirstName', 'LastName', 'FullName',
#        'HeadshotUrl', 'CountryCode', 'Position', 'ClassifiedPosition',
#        'GridPosition', 'Q1', 'Q2', 'Q3', 'Time', 'Status', 'Points'],
#       dtype='object')

# %%
df_avg_position = df.groupby('TeamName')['Position'].mean().reset_index()
df_avg_position.columns = ['TeamName', 'AvgPosition']

df_avg_position
# Out:
#           TeamName  AvgPosition
# 0           Alpine         15.0
# 1     Aston Martin         11.0
# 2          Ferrari          6.0
# 3     Haas F1 Team         14.0
# 4      Kick Sauber         15.5
# 5          McLaren          2.0
# 6         Mercedes          5.0
# 7               RB         15.0
# 8  Red Bull Racing          6.0
# 9         Williams         15.5

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Q1                    20
# Q3                    20
# Q2                    20
# Time                  13
# DriverNumber           0
# TeamName               0
# DriverId               0
# Abbreviation           0
# BroadcastName          0
# TeamColor              0
# TeamId                 0
# FirstName              0
# LastName               0
# Position               0
# CountryCode            0
# HeadshotUrl            0
# FullName               0
# ClassifiedPosition     0
# GridPosition           0
# Status                 0
# Points                 0
# dtype: int64

# %%
df.apply(pd.Series.nunique)
# Out:
# DriverNumber          20
# BroadcastName         20
# Abbreviation          20
# DriverId              20
# TeamName              10
# TeamColor             10
# TeamId                10
# FirstName             20
# LastName              20
# FullName              20
# HeadshotUrl           20
# CountryCode           15
# Position              20
# ClassifiedPosition    20
# GridPosition          20
# Q1                     0
# Q2                     0
# Q3                     0
# Time                   7
# Status                 4
# Points                11
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# DriverNumber           0
# BroadcastName          0
# Abbreviation           0
# DriverId               0
# TeamName               0
# TeamColor              0
# TeamId                 0
# FirstName              0
# LastName               0
# FullName               0
# HeadshotUrl            0
# CountryCode            0
# Position               0
# ClassifiedPosition     0
# GridPosition           0
# Q1                    20
# Q2                    20
# Q3                    20
# Time                  13
# Status                 0
# Points                 0
# dtype: int64

# %% [markdown]
# # Begin Data cleaning

# %%
# Creating the dictionary structure with each team name as a key
team_dfs = {}

# Iterating through the unique team names
for team in df['TeamName'].unique():
    # Filter the DataFrame for the current team
    team_df = df[df['TeamName'] == team]
    
    # Extract the relevant information
    avg_position = team_df['Position'].mean()
    team_color = team_df['TeamColor'].iloc[0]
    team_id = team_df['TeamId'].iloc[0]
    
    # Creating the new DataFrame for the team
    team_summary_df = pd.DataFrame({
        'AvgPosition': [avg_position],
        'TeamColor': [team_color],
        'TeamId': [team_id],
    })
    
    # Adding the new DataFrame to the dictionary
    team_dfs[team] = team_summary_df

team_dfs
# Out:
# {'McLaren':    AvgPosition TeamColor   TeamId
#  0          2.0    FF8000  mclaren,
#  'Red Bull Racing':    AvgPosition TeamColor    TeamId
#  0          6.0    3671C6  red_bull,
#  'Mercedes':    AvgPosition TeamColor    TeamId
#  0          5.0    27F4D2  mercedes,
#  'Ferrari':    AvgPosition TeamColor   TeamId
#  0          6.0    E80020  ferrari,
#  'Aston Martin':    AvgPosition TeamColor        TeamId
#  0         11.0    229971  aston_martin,
#  'Haas F1 Team':    AvgPosition TeamColor TeamId
#  0         14.0    B6BABD   haas,
#  'Williams':    AvgPosition TeamColor    TeamId
#  0         15.5    64C4FF  williams,
#  'RB':    AvgPosition TeamColor TeamId
#  0         15.0    6692FF     rb,
#  'Alpine':    AvgPosition TeamColor  TeamId
#  0         15.0    0093cc  alpine,
#  'Kick Sauber':    AvgPosition TeamColor  TeamId
#  0         15.5    52e252  sauber}

# %%
for k, v in team_dfs.items():
    print(type(k))
    print(type(v))
# Out:
# <class 'str'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'str'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'str'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'str'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'str'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'str'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'str'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'str'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'str'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'str'>
# <class 'pandas.core.frame.DataFrame'>
